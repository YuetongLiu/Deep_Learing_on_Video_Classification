# %% [markdown]
# # 682.Final Project - Video Classfication

# %%
try:
    from google.colab import drive
    drive.mount('/content/drive')
except:
    print("Mounting Failed.")
# Out:
# Mounted at /content/drive

# %% [markdown]
# For each epoch, the first "Validation set result" is the validation set result. The second "Validation set result" is the Test set result.

# %%
# !python "/content/drive/Shareddrives/682 final project/video-classification-master/Conv3D/Copy of UCF101_3DCNN.py"
# Out:
# cuda
# [4 7 2 ... 7 7 2]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:477: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:1709: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Train Epoch: 1 [200/1370 (14%)]	Loss: 2.291624, Accu: 10.00%
# Train Epoch: 1 [400/1370 (29%)]	Loss: 2.266893, Accu: 15.00%
# Train Epoch: 1 [600/1370 (43%)]	Loss: 2.232947, Accu: 30.00%
# Train Epoch: 1 [800/1370 (58%)]	Loss: 2.243308, Accu: 25.00%
# ...
